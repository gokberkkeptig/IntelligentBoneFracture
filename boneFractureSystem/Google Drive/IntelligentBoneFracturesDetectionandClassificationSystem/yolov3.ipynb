# %%
#!ls '/content/drive/MyDrive/Intelligent Bone Fractures Detection and Classification System/Dataset/trainAllData'

# %%
#%cd '/content/drive/MyDrive/Intelligent Bone Fractures Detection and Classification System/Darknet'
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/Intelligent Bone Fractures Detection and Classification System/Darknet'
# /content/drive/MyDrive/Intelligent Bone Fractures Detection and Classification System/DarkNetObjFiles

# %%
# %cd ..
# Out:
# /content/drive/My Drive/Intelligent Bone Fractures Detection and Classification System/DarkNetObjFiles

# %%
# !ls
# Out:
# adc.json  drive  Google_drive  mycreds.json  sample_data

# %%
from google.colab import drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#NEW
import zipfile
with zipfile.ZipFile("/content/DarkNetObjFiles.zip", 'r') as zip_ref:
    zip_ref.extractall("/content/DarkNet")

# %%
#NEW
# !/content/DarkNet/DarkNetObjFiles/Darknet/darknet detector train /content/DarkNet/DarkNetObjFiles/Darknet/data/obj/labelled_data.data /content/DarkNet/DarkNetObjFiles/Darknet/cfg/yolov3-custom.cfg /content/DarkNet/DarkNetObjFiles/objWeight/darknet53.conv.74 -dont_show

# %%
# !python /content/drive/MyDrive/IntelligentBoneFracturesDetectionandClassificationSystem/DarkNetObjFiles/creating-files-data-and-name.py

# %%
# !python /content/drive/MyDrive/IntelligentBoneFracturesDetectionandClassificationSystem/DarkNetObjFiles/creating-train-and-test-txt-files.py

# %%
# !/content/drive/MyDrive/IntelligentBoneFracturesDetectionandClassificationSystem/DarkNetObjFiles/Darknet/darknet detector train /content/drive/MyDrive/IntelligentBoneFracturesDetectionandClassificationSystem/DarkNetObjFiles/Darknet/data/obj/labelled_data.data /content/drive/MyDrive/IntelligentBoneFracturesDetectionandClassificationSystem/DarkNetObjFiles/Darknet/cfg/yolov3-custom.cfg /content/drive/MyDrive/IntelligentBoneFracturesDetectionandClassificationSystem/DarkNetObjFiles/objWeight/darknet53.conv.74 -dont_show

# %%
# !nvidia-smi

# %%
# !Darknet/darknet detector train Darknet/data/obj/labelled_data.data Darknet/cfg/yolov3-custom.cfg objWeight/darknet53.conv.74 -dont_show
# Out:
# /bin/bash: Darknet/darknet: No such file or directory

# %%
# !pip install -U -q PyDrive
# these classes allow you to request the Google drive API
import os
import glob
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive 
from google.colab import auth 
from oauth2client.client import GoogleCredentials

# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
#!find . -type f -name "*.cfg" -print0 | xargs -0 dos2unix

# %%
# %cd /content/drive/MyDrive/Intelligent Bone Fractures Detection and Classification System/DarkNetObjFiles
# Out:
# /content/drive/.shortcut-targets-by-id/1A-bOR9giyk2rh52lYNu51Q9r6JUbF7VP/Intelligent Bone Fractures Detection and Classification System/DarkNetObjFiles

# %%
# !chmod +x /content/drive/MyDrive/IntelligentBoneFracturesDetectionandClassificationSystem/DarkNetObjFiles/Darknet/darknet

# %%
#NEW
# !chmod +x /content/DarkNet/DarkNetObjFiles/Darknet/darknet

# %%
#NEW
# !python /content/DarkNet/DarkNetObjFiles/creating-files-data-and-name.py

# %%
#NEW
# !python /content/DarkNet/DarkNetObjFiles/creating-train-and-test-txt-files.py
